# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Connectors"

# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Generic"

# %%
from pyspark.sql.functions import *

# %%
adls_connect()

# %%
list_bronze_files()

# %%
disease_df = read_bronze_file_csv("disease")

# %%
display(disease_df.limit(5))

# %%
rows_column_count(disease_df)

# %%
check_missing_values(disease_df,disease_df.columns)

# %%
check_string_value_as_nan(disease_df)

# %%
check_missing_values_percentage(disease_df,disease_df.columns)

# %%
check_missing_values_percentage_v1(disease_df,disease_df.columns)

# %%
# Check disease_name like Flu,Bladder cancer to find the subgrp_id
#display(disease_df.select("subgrp_id").filter(col("disease_name").like("%Bladder cancer%")))

# %% [markdown]
# Writing to Silver layer

# %%
write_to_silver(disease_df,"disease_S.csv")
