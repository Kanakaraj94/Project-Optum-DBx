# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Connectors"

# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Generic"

# %%
from pyspark.sql.functions import *

# %%
adls_connect()

# %%
list_bronze_files()

# %%
grp_df = read_bronze_file_csv("group")

# %%
display(grp_df.limit(5))

# %%
rows_column_count(grp_df)

# %%
check_missing_values(grp_df,grp_df.columns)

# %%
check_string_value_as_nan(grp_df)

# %%
check_missing_values_percentage(grp_df,grp_df.columns)

# %%
check_missing_values_percentage_v1(grp_df,grp_df.columns)

# %% [markdown]
# Writing to Silver layer

# %%
write_to_silver(grp_df,"group_S.csv")
