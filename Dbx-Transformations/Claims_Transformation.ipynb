# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Connectors"

# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Generic"

# %%
#Importing neccessary libraries
from pyspark.sql.functions import *

# %%
#Calling the function to connect to ADLS storage from Connectors
adls_connect()

# %%
#Listing all the files in Bronze layer
list_bronze_files()

# %%
#Reading Subgroup.csv file from Bronze layer
claims_df = read_bronze_file_json("Claims")

# %%
display(claims_df.limit(5))

# %%
rows_column_count(claims_df)

# %%
check_missing_values(claims_df,claims_df.columns)

# %%
claims_df = claims_df.drop("_id")

# %%
check_string_value_as_nan(claims_df)

# %%
claims_df = claims_df.replace("NaN",None)

# %%
check_string_value_as_nan(claims_df)

# %%
check_missing_values_percentage(claims_df,claims_df.columns)

# %%
check_missing_values_percentage_v1(claims_df,claims_df.columns)

# %%
display(claims_df.limit(5))

# %% [markdown]
# Transformation Layer

# %%
# Filling missing values
claims_df = claims_df.fillna({"Claim_Or_Rejected":"N"})

# %%
check_missing_values_percentage_v1(claims_df,claims_df.columns)

# %%
# Casting from String type to integer
claims_df = claims_df.withColumn("claim_amount",claims_df["claim_amount"].cast("integer"))

# %%
display(claims_df.limit(5))

# %%
#display(claims_df.select("*").filter(col("SUB_ID") == "SUBID10049"))

# %% [markdown]
# Writing to Silver layer

# %%
#Writing transformed dataframe into Silver layer
write_to_silver(claims_df,"claims_S.csv")
