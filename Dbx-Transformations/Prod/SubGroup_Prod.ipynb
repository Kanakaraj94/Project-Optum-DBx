# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Prod/Connectors_Prod"

# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Prod/Generic_Prod"

# %%
#Importing neccessary libraries
from pyspark.sql.functions import *

# %%
#Calling the function to connect to ADLS storage from Connectors
adls_connect()

# %%
#Listing all the files in Bronze layer
list_bronze_files()

# %%
#Reading Subgroup.csv file from Bronze layer
subgrp_df = read_bronze_file_csv("subgroup")

# %%
check_missing_values(subgrp_df,subgrp_df.columns)

# %%
check_string_value_as_nan(subgrp_df)

# %% [markdown]
# Transformation Layer

# %%
#Data Cleaning-Segregating comma seperated Values into seperate rows
subgrp_df = subgrp_df.withColumn("subgrp_id",split("subgrp_id",","))

# %%
subgrp_df = subgrp_df.withColumn("subgrp_id",explode("subgrp_id"))

# %% [markdown]
# Writing to Silver layer

# %%
#Writing transformed dataframe into Silver layer
write_to_silver(subgrp_df,"subgroup_S.csv")
