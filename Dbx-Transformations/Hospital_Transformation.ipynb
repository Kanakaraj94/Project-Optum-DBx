# %%
spark.conf.set(
    "fs.azure.account.key.adlsdataoptum.dfs.core.windows.net",
    dbutils.secrets.get(scope="optumScope", key="AdlsAccessKey"))

# %%
display(dbutils.secrets.listScopes())

# %%
display(dbutils.secrets.list("optumScope"))

# %%
display(dbutils.fs.ls("abfss://optum@adlsdataoptum.dfs.core.windows.net/medallion/bronze"))

# %%
hos_df = spark.read.csv("abfss://optum@adlsdataoptum.dfs.core.windows.net/medallion/bronze/Hospital.csv", header=True, inferSchema=True)

# %%
display(hos_df.limit(5))
