# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Connectors"

# %%
# %run "/Workspace/Optum-DBx/Project-Optum-DBx/Dbx-Transformations/Generic"

# %%
from pyspark.sql.functions import *

# %%
adls_connect()

# %%
display(dbutils.secrets.listScopes())

# %%
display(dbutils.secrets.list("optumScope"))

# %%
list_bronze_files()

# %%
hos_df = read_bronze_file_csv("Hospital")

# %%
display_data(hos_df)

# %%
rows_column_count(hos_df)

# %%
check_duplicates(hos_df,hos_df.columns)

# %%
check_missing_values_percentage(hos_df,hos_df.columns)

# %%
check_missing_values_percentage_v1(hos_df,hos_df.columns)

# %%
check_missing_values(hos_df,hos_df.columns)

# %%
check_string_value_as_nan(hos_df)

# %% [markdown]
# Actuall Transformation

# %%
# Replacing NaN with actuall Null
hos_df = hos_df.replace("NaN",None)

# %%
display_data(hos_df)

# %%
# Filling Null Values
hos_df = hos_df.fillna({"state":"UT"})

# %%
display_data(hos_df)

# %%
# Replacing duplicate values
hos_df = hos_df.replace({"New Delhi": "Delhi"})

# %%
display_data(hos_df)

# %% [markdown]
#  Writing to Silver layer

# %%
write_to_silver(hos_df,"Hospital_S.csv")
